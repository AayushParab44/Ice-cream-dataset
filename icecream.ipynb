# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ice=pd.read_csv(r'C:\Users\AAYUSH\Desktop\icecream\ice.csv')
# print(ice)

ice.head()
# Out:
#          DATE    value
# 0  01/01/1972  59.9622
# 1  01/02/1972  67.0605
# 2  01/03/1972  74.2350
# 3  01/04/1972  78.1120
# 4  01/05/1972  84.7636

# %%
ice.describe()
# Out:
#             value
# count  576.000000
# mean   109.750888
# std     27.950383
# min     58.659800
# 25%     88.793525
# 50%    107.506250
# 75%    128.018650
# max    196.173700

# %%
ice.plot.scatter(x='DATE',y='value',figsize=(12,3))
# Out:
# <AxesSubplot:xlabel='DATE', ylabel='value'>

# %%
ice['year']=ice['DATE'].map(lambda date:date[6:])

# %%
ice
# Out:
#            DATE     value  year
# 0    01/01/1972   59.9622  1972
# 1    01/02/1972   67.0605  1972
# 2    01/03/1972   74.2350  1972
# 3    01/04/1972   78.1120  1972
# 4    01/05/1972   84.7636  1972
# ..          ...       ...   ...
# 571  01/08/2019  102.6085  2019
# 572  01/09/2019  100.1741  2019
# 573  01/10/2019   90.1684  2019
# 574  01/11/2019   79.7223  2019
# 575  01/12/2019   77.8855  2019
#
# [576 rows x 3 columns]

# %%
icecream_data=ice
icecream_data.head()
# Out:
#          DATE    value  year
# 0  01/01/1972  59.9622  1972
# 1  01/02/1972  67.0605  1972
# 2  01/03/1972  74.2350  1972
# 3  01/04/1972  78.1120  1972
# 4  01/05/1972  84.7636  1972

# %%
icecream_data.head()
# Out:
#          DATE    value  year
# 0  01/01/1972  59.9622  1972
# 1  01/02/1972  67.0605  1972
# 2  01/03/1972  74.2350  1972
# 3  01/04/1972  78.1120  1972
# 4  01/05/1972  84.7636  1972

# %%
a=icecream_data.groupby(['year']).mean()

a.head()
a.describe()
# Out:
#             value
# count   48.000000
# mean   109.750888
# std     20.406961
# min     78.073117
# 25%     95.566987
# 50%    104.681400
# 75%    124.067008
# max    156.029642

# %%
icecream_data
# Out:
#            DATE     value  year
# 0    01/01/1972   59.9622  1972
# 1    01/02/1972   67.0605  1972
# 2    01/03/1972   74.2350  1972
# 3    01/04/1972   78.1120  1972
# 4    01/05/1972   84.7636  1972
# ..          ...       ...   ...
# 571  01/08/2019  102.6085  2019
# 572  01/09/2019  100.1741  2019
# 573  01/10/2019   90.1684  2019
# 574  01/11/2019   79.7223  2019
# 575  01/12/2019   77.8855  2019
#
# [576 rows x 3 columns]

# %%
fig=plt.gcf()
fig.set_size_inches(26, 8)
sns.scatterplot(x='year',y='value',data=a,)
# Out:
# <AxesSubplot:xlabel='year', ylabel='value'>

# %% [markdown]
# Conclusion- The average icecream sales had gone up in the years 1992 to 2005 and then went back to what they were in around the 1980s.
